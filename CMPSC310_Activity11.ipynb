# %% [markdown]
# <a href="https://colab.research.google.com/github/CMPSC-310-AI-Spring2023/activity11_distributions_bayes-cheng-cs/blob/main/CMPSC310_Activity11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Activity 11: Distributions and Bayes Algorithm **

# %% [markdown]
# ## Binomial Distribution
#
# prints what is within binomials

# %%
import numpy as np

n=100 # number of trials
p=0.5 # probability of success
s=100 # size
binomial = np.random.binomial(n,p,s)
print(binomial)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 100])
plt.plot(binomial,linewidth=2, color='r')
plt.show()
# Out:
# [47 52 51 52 59 52 51 50 51 53 57 56 48 55 47 42 51 49 58 52 59 37 49 48
#  52 52 44 43 46 54 52 51 58 53 53 49 55 56 53 46 55 49 49 42 39 54 49 40
#  41 46 56 49 55 40 53 46 44 51 55 46 50 48 61 44 55 46 63 55 58 48 54 49
#  52 48 49 47 50 51 62 46 37 54 48 55 51 50 65 45 47 56 50 60 52 57 53 49
#  46 43 44 49]

# %% [markdown]
# ## Uniform Distribution
#
# Similar to question 1, but this time the low, high is and size is bounded.

# %%
import numpy as np

uniform = np.random.uniform(low=1, high=10,size=100)
print(uniform)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 10])
plt.plot(uniform,linewidth=2, color='r')
plt.show()
# Out:
# [2.88045636 8.0181856  4.55471897 2.96302533 7.03177916 5.44279935
#  2.67634395 8.80624565 8.29135332 9.23636578 7.4206968  9.25927548
#  9.42211528 8.59158386 9.1638538  7.49602224 7.6395733  5.40131526
#  5.39904884 8.62759592 9.28325378 5.49927067 8.81403611 4.96678631
#  1.50319935 3.50094042 6.25506288 9.45405666 6.34297999 3.2515943
#  5.45692983 9.61802914 7.24246232 4.22122821 5.9899927  1.31921446
#  4.4137985  3.35333058 8.21483103 4.65711948 2.28030189 9.75360178
#  5.47868084 4.72792302 2.95688112 2.59475824 6.37850516 2.4025295
#  7.61298794 2.26157336 2.86285719 6.1757774  5.6740034  7.17941607
#  4.98310784 5.4994669  4.86072382 2.46031983 1.50770524 5.39243984
#  8.3749169  7.59841439 2.41985804 3.77742135 6.64732974 5.2021428
#  5.43810582 7.45954225 4.48724338 1.34570596 8.57738314 7.86035369
#  1.41260356 5.34466207 5.99227736 6.93100494 6.34396845 1.91733515
#  4.75677327 4.29817872 4.28903693 2.79863426 9.11271351 8.23891395
#  2.54766927 4.50205099 6.94214417 3.00816615 9.43010711 3.03629958
#  5.7062811  4.49521937 1.64905645 7.70066948 3.36609548 7.63664049
#  5.13214973 5.83094395 6.69262396 8.88990147]

# %% [markdown]
# ## Normal Distribution
#
# the axis is set in this example

# %%
import numpy as np
mu, sigma = 0, 0.1 # mean and standard deviation
normal = np.random.normal(mu, sigma, 100)

import matplotlib.pyplot as plt

plt.axis([0, 100, 0, 1])
plt.plot(normal,linewidth=2, color='r')
plt.show()

# %% [markdown]
# ## Bayes Algorithm
#
#
#
# Ref: https://scikit-learn.org/stable/modules/naive_bayes.html

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB # Gaussian is normal distribution
import matplotlib.pyplot as plt

X, y = load_iris(return_X_y=True) # https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
print("Number of mislabeled points out of a total %d points : %d" % (X_test.shape[0], (y_test != y_pred).sum()))
plt.plot(normal,linewidth=2, color='r')
plt.show()
# Out:
# Number of mislabeled points out of a total 75 points : 4
